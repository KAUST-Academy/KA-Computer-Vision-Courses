# %%
from IPython.display import clear_output

# %%
# %pip install torch torchvision

clear_output()

# %% [markdown]
# ## Contents
#
# - Download and load the pre-trained resnet model
# - Replace it's output layers with new layer which can classify Cifar-10 dataset(the final layer now classifies in 10 classes and not 1000 which is resnet's default)
# - Train this new model on Cifar-10
# - Show performance of the model on unseen data

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import transforms
from torchvision.models import resnet18
from torch.utils.data import DataLoader
from torchvision.datasets import CIFAR10

# %% [markdown]
# ## Download and Load the dataset

# %%
transform_train = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
])

train_dataset = CIFAR10(root='./data', train=True, download=True, transform=transform_train)
test_dataset = CIFAR10(root='./data', train=False, download=True, transform=transform_test)

# %% [markdown]
# ## Download and Load the model

# %% [markdown]
# ## Fine tuning on Cifar-10

# %% [markdown]
# ### Post training accuracy
#
# Show performance of the model on unseen data
