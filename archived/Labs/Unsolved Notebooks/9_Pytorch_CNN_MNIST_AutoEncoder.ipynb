# %%
from IPython.display import clear_output

# %%
# %pip install torch torchvision torchsummary
# %pip install numpy
# %pip install matplotlib

clear_output()

# %%
import torch
import numpy as np
import torch.nn as nn
from torchvision import transforms
from torchvision.datasets import MNIST
from torch.utils.data.sampler import SubsetRandomSampler
from torchsummary import summary
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid

# %% [markdown]
# ## Contents
#
# In this notebook, you'll train an Auto Encoder model and generate images from it. The images we'll train on and generate are MNIST images (0-9 digits).
# This time, we'll utilize the power of CNN instead of limiting ourselves to linear layers
#
# - Define and then train the CNN model on MNIST images
# - Show your model's performance by generating and visualizing some images using it.

# %% [markdown]
# ## Loading the dataset

# %%
batch_size = 64

train_transforms = transforms.Compose([
                        # transforms.RandomCrop(28, padding=4),
                        transforms.ToTensor(),
                    ])

train_data = MNIST(root='./datasets', train=True, download=True, transform=train_transforms)

# %% [markdown]
# ## Define the model

# %% [markdown]
# ## Training the model

# %% [markdown]
# ## Test the model
#
# generate some images using the model and display them
